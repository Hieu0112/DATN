# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# %%
import string
from pyvi import ViTokenizer

# %%
data = [
    "ai ai Con mèo đang ngủ trên chiếc ghế sofa.",
    "Con chó chạy quanh sân chơi và vui vẻ.",
    "Con mèo và con chó cùng chơi với nhau.",
    "Con mèo thích ăn cá, còn con chó thích ăn xương.",
    "Con mèo rất đáng yêu và thông minh.",
]

# %%
stopwords = ["ai",'ai_ai', 'ai_nấy', 'ai_đó', 'bao_lâu', 'bao_nhiêu', 'biết', 'biết_bao', 'biết_chắc', "và","với"]

# %%
def tokenizerVN(text):
    return ViTokenizer.tokenize(text)

# Định nghĩa tokenize
def tokenize(sentence):
    # Tokenize và loại bỏ dấu câu
    tokens = tokenizerVN(sentence).split()
    tokens = [word for word in tokens if word not in string.punctuation]  # Loại bỏ dấu câu
    return tokens

# %%
# Khởi tạo TfidfVectorizer
# Tạo CountVectorizer
vectorizerCV = TfidfVectorizer(
    stop_words=stopwords,
    tokenizer=tokenize,
)
# Set pandas options to display full data
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.width', None)  # Auto-detect width
pd.set_option('display.max_colwidth', None)  # Show full content of each column
# Chuyển đổi các câu thành ma trận TF-IDF
X = vectorizerCV.fit_transform(data)

# Chuyển ma trận thành DataFrame để dễ dàng xem
df = pd.DataFrame(X.toarray(), columns=vectorizerCV.get_feature_names_out())

# In kết quả
print(df)
# Out:
#       chiếc       chó     chơi      chạy       con        cá       còn  \
# 0  0.390898  0.000000  0.00000  0.000000  0.186265  0.000000  0.000000
# 1  0.000000  0.309721  0.00000  0.462469  0.220369  0.000000  0.000000
# 2  0.000000  0.309768  0.46254  0.000000  0.440805  0.000000  0.000000
# 3  0.000000  0.188117  0.00000  0.000000  0.267694  0.280893  0.280893
# 4  0.000000  0.000000  0.00000  0.000000  0.223525  0.000000  0.000000
#
#       cùng       ghế       mèo       ngủ     nhau     quanh       rất  \
# 0  0.00000  0.390898  0.220225  0.390898  0.00000  0.000000  0.000000
# 1  0.00000  0.000000  0.000000  0.000000  0.00000  0.462469  0.000000
# 2  0.46254  0.000000  0.260587  0.000000  0.46254  0.000000  0.000000
# 3  0.00000  0.000000  0.158250  0.000000  0.00000  0.000000  0.000000
# 4  0.00000  0.000000  0.264279  0.000000  0.00000  0.000000  0.469093
#
#        sofa  sân_chơi     thích  thông_minh      trên    vui_vẻ     xương  \
# 0  0.390898  0.000000  0.000000    0.000000  0.390898  0.000000  0.000000
# 1  0.000000  0.462469  0.000000    0.000000  0.000000  0.462469  0.000000
# 2  0.000000  0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.561786    0.000000  0.000000  0.000000  0.280893
# 4  0.000000  0.000000  0.000000    0.469093  0.000000  0.000000  0.000000
#
#         yêu        ăn      đang      đáng
# 0  0.000000  0.000000  0.390898  0.000000
# 1  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.561786  0.000000  0.000000
# 4  0.469093  0.000000  0.000000  0.469093
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
